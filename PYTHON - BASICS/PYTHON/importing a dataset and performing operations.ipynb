# %%
import pandas as pd
import numpy as np
datset=pd.read_csv("C:\\Users\\Srianvika S\\Downloads\\archive\\insta.csv.csv")
dataset
a = np.array([[1, 2], [3, 4]]) 
print a
# Out:
#     Unnamed: 0                  Rank              Username  \
# 0            0                     1            @instagram
# 1            1                     2            @cristiano
# 2            2                     3             @leomessi
# 3            3                     4          @kyliejenner
# 4            4                     5          @selenagomez
# 5            5                     6              @therock
# 6            6                     7         @arianagrande
# 7            7                     8        @kimkardashian
# 8            8                     9              @beyonce
# 9            9                    10      @khloekardashian
# 10          10                    11         @justinbieber
# 11          11                    12        @kendalljenner
# 12          12                    13                 @nike
# 13          13                    14               @natgeo
# 14          14                    15          @taylorswift
# ...

# %%
dataset.head()
# Out:
#    Unnamed: 0 Rank      Username              Owner Followers(millions)[2]  \
# 0           0    1    @instagram          Instagram                    586
# 1           1    2    @cristiano  Cristiano Ronaldo                    531
# 2           2    3     @leomessi       Lionel Messi                    417
# 3           3    4  @kyliejenner       Kylie Jenner                    377
# 4           4    5  @selenagomez       Selena Gomez                    367
#
#                                Profession/Activity Country/Continent
# 0                            Social media platform     United States
# 1                                       Footballer          Portugal
# 2                                       Footballer         Argentina
# 3  Television personality, model and businesswoman     United States
# 4             Musician, actress, and businesswoman     United States

# %%
a = np.array([[1, 2], [3, 4]]) 
print(a)
# Out:
# [[1 2]
#  [3 4]]

# %%
dataset.min()
# Out:
# Unnamed: 0                          0
# Rank                                1
# Username                  @aliaabhatt
# Owner                      Alia Bhatt
# Followers(millions)[2]            101
# Profession/Activity             Actor
# Country/Continent           Argentina
# dtype: object

# %%
dataset.max()
# Out:
# Unnamed: 0                                                             50
# Rank                                                 As of 4 January 2023
# Username                                             As of 4 January 2023
# Owner                                                             Zendaya
# Followers(millions)[2]                               As of 4 January 2023
# Profession/Activity       Television personality, model and businesswoman
# Country/Continent                                           United States
# dtype: object
